# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv1D, GlobalMaxPooling1D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from transformers import BertTokenizer, TFBertModel
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# 2024-12-13 06:08:20.143337: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-13 06:08:20.826205: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load dataset
data = pd.read_csv("stock_data.csv")
data
# Out:
#                                                    Text  Sentiment
# 0     Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1     user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2     user I'd be afraid to short AMZN - they are lo...          1
# 3                                     MNTA Over 12.00            1
# 4                                      OI  Over 21.37            1
# ...                                                 ...        ...
# 5786  Industry body CII said #discoms are likely to ...         -1
# 5787  #Gold prices slip below Rs 46,000 as #investor...         -1
# 5788  Workers at Bajaj Auto have agreed to a 10% wag...          1
# 5789  #Sharemarket LIVE: Sensex off day’s high, up 6...          1
# 5790  #Sensex, #Nifty climb off day's highs, still u...          1
#
# [5791 rows x 2 columns]

# %%
# Preprocess dataset
data['Sentiment'] = data['Sentiment'].apply(lambda x: 1 if x == 1 else 0)
texts = data['Text'].values
sentiments = data['Sentiment'].values

# %%
texts
# Out:
# array(['Kickers on my watchlist XIDE TIT SOQ PNK CPW BPZ AJ  trade method 1 or method 2, see prev posts',
#        'user: AAP MOVIE. 55% return for the FEA/GEED indicator just 15 trades for the year.  AWESOME.  ',
#        "user I'd be afraid to short AMZN - they are looking like a near-monopoly in eBooks and infrastructure-as-a-service",
#        ...,
#        'Workers at Bajaj Auto have agreed to a 10% wage cut for the period between April 15 and till the lockdown is lifted. https://t.co/RgvrKPliNd',
#        '#Sharemarket LIVE: Sensex off day’s high, up 600 points, #Nifty tests 9,200, #TCS, private bank stocks lead\nhttps://t.co/3xgtLroKUI',
#        "#Sensex, #Nifty climb off day's highs, still up 2%; Key factors driving D-Street higher today https://t.co/jVQcousFp6"],
#       dtype=object)

# %%
sentiments
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize and pad/truncate the data
def tokenize_data(texts, tokenizer, max_len=128):
    encodings = tokenizer(
        list(texts),
        truncation=True,
        padding='max_length',  # Ensure all sequences are of max_len
        max_length=max_len,
        return_tensors='tf'
    )
    return encodings

max_len = 128
encodings = tokenize_data(texts, tokenizer, max_len=max_len)
# Out:
# 2024-12-13 06:08:26.318174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11541 MB memory:  -> device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:19:00.0, compute capability: 6.1
# 2024-12-13 06:08:26.318779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11541 MB memory:  -> device: 1, name: NVIDIA TITAN Xp, pci bus id: 0000:1a:00.0, compute capability: 6.1
# 2024-12-13 06:08:26.319330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 11541 MB memory:  -> device: 2, name: NVIDIA TITAN Xp, pci bus id: 0000:67:00.0, compute capability: 6.1
# 2024-12-13 06:08:26.319840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 11533 MB memory:  -> device: 3, name: NVIDIA TITAN Xp, pci bus id: 0000:68:00.0, compute capability: 6.1

# %%
# Convert to NumPy arrays
input_ids_np = encodings['input_ids'].numpy()
attention_mask_np = encodings['attention_mask'].numpy()

# Split dataset
train_inputs, test_inputs, train_labels, test_labels = train_test_split(
    input_ids_np, sentiments, test_size=0.2, random_state=42
)

train_attention, test_attention = train_test_split(
    attention_mask_np, test_size=0.2, random_state=42
)

print(f"Train inputs shape: {train_inputs.shape}")
print(f"Train attention shape: {train_attention.shape}")
# Out:
# Train inputs shape: (4632, 128)
# Train attention shape: (4632, 128)

# %%
# BERT Model
bert_model = TFBertModel.from_pretrained('bert-base-uncased')

# Define the model
input_ids = Input(shape=(max_len,), dtype=tf.int32, name='input_ids')
attention_mask = Input(shape=(max_len,), dtype=tf.int32, name='attention_mask')

bert_output = bert_model(input_ids, attention_mask=attention_mask)
sequence_output = bert_output.last_hidden_state

bert_model.trainable = True  

# Freeze the pooler layer
for layer in bert_model.layers:
    if 'pooler' in layer.name:
        layer.trainable = False

# CNN layers
conv1 = Conv1D(filters=128, kernel_size=3, activation='relu')(sequence_output)
pool2 = GlobalMaxPooling1D()(conv1)

# Fully connected layer
fc1 = Dense(128, activation='relu')(pool2)
fc2 = Dense(32, activation='relu')(fc1)
dropout1 = Dropout(0.3)(fc2)
output = Dense(1, activation='relu')(dropout1)

# Compile model
model = Model(inputs=[input_ids, attention_mask], outputs=output)
model.compile(optimizer=Adam(learning_rate=2e-5), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model (TFBertModel  TFBaseModelOutputWithPooli   1094822   ['input_ids[0][0]',
#  )                           ngAndCrossAttentions(last_   40         'attention_mask[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  conv1d (Conv1D)             (None, 126, 128)             295040    ['tf_bert_model[0][0]']
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_max_pooling1d[0][0]']
#
#  dense_1 (Dense)             (None, 32)                   4128      ['dense[0][0]']
#
#  dropout_37 (Dropout)        (None, 32)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    33        ['dropout_37[0][0]']
#
# ==================================================================================================
# Total params: 109797953 (418.85 MB)
# Trainable params: 109797953 (418.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Model Checkpoint
checkpoint_callback = ModelCheckpoint(
    'bert_cnn_sentiment_model_2layers.h5',         
    monitor='val_loss',      
    save_best_only=True,      
    mode='min',               
    verbose=1                 
)

# Training
history = model.fit(
    [train_inputs, train_attention],
    train_labels,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2024-12-13 06:08:45.608132: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-12-13 06:08:45.767369: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd1405cbfe0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-13 06:08:45.767417: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN Xp, Compute Capability 6.1
# 2024-12-13 06:08:45.767432: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA TITAN Xp, Compute Capability 6.1
# 2024-12-13 06:08:45.767443: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA TITAN Xp, Compute Capability 6.1
# 2024-12-13 06:08:45.767454: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA TITAN Xp, Compute Capability 6.1
# 2024-12-13 06:08:45.775576: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-13 06:08:45.806860: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:543] Can't find libdevice directory ${CUDA_DIR}/nvvm/libdevice. This may result in compilation or runtime failures, if the program we try to run uses routines from libdevice.
# Searched for CUDA in the following directories:
#   ./cuda_sdk_lib
#   /usr/local/cuda-11.8
#   /usr/local/cuda
#   .
# You can choose the search directory by setting xla_gpu_cuda_data_dir in HloModule's DebugOptions.  For most apps, setting the environment variable XLA_FLAGS=--xla_gpu_cuda_data_dir=/path/to/cuda will work.
# 2024-12-13 06:08:45.909143: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 116/116 [==============================] - ETA: 0s - loss: 2.5513 - accuracy: 0.5614
# Epoch 1: val_loss improved from inf to 1.01413, saving model to bert_cnn_sentiment_model_2layers.h5
# /home/deeptimaan/.conda/envs/venv-p39-tf2/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 116/116 [==============================] - 89s 524ms/step - loss: 2.5513 - accuracy: 0.5614 - val_loss: 1.0141 - val_accuracy: 0.6311
# Epoch 2/100
# 116/116 [==============================] - ETA: 0s - loss: 1.7519 - accuracy: 0.5665
# Epoch 2: val_loss improved from 1.01413 to 0.67985, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 60s 520ms/step - loss: 1.7519 - accuracy: 0.5665 - val_loss: 0.6798 - val_accuracy: 0.6160
# Epoch 3/100
# 116/116 [==============================] - ETA: 0s - loss: 0.8248 - accuracy: 0.5190
# Epoch 3: val_loss improved from 0.67985 to 0.67089, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 61s 524ms/step - loss: 0.8248 - accuracy: 0.5190 - val_loss: 0.6709 - val_accuracy: 0.6149
# Epoch 4/100
# 116/116 [==============================] - ETA: 0s - loss: 0.7520 - accuracy: 0.5571
# Epoch 4: val_loss did not improve from 0.67089
# 116/116 [==============================] - 54s 469ms/step - loss: 0.7520 - accuracy: 0.5571 - val_loss: 0.7058 - val_accuracy: 0.4930
# Epoch 5/100
# 116/116 [==============================] - ETA: 0s - loss: 0.7322 - accuracy: 0.5644
# Epoch 5: val_loss improved from 0.67089 to 0.64836, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 535ms/step - loss: 0.7322 - accuracy: 0.5644 - val_loss: 0.6484 - val_accuracy: 0.6343
# Epoch 6/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6977 - accuracy: 0.5976
# Epoch 6: val_loss improved from 0.64836 to 0.62322, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 61s 530ms/step - loss: 0.6977 - accuracy: 0.5976 - val_loss: 0.6232 - val_accuracy: 0.6688
# Epoch 7/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6954 - accuracy: 0.6081
# Epoch 7: val_loss did not improve from 0.62322
# 116/116 [==============================] - 55s 471ms/step - loss: 0.6954 - accuracy: 0.6081 - val_loss: 0.6557 - val_accuracy: 0.6192
# Epoch 8/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6703 - accuracy: 0.6148
# Epoch 8: val_loss improved from 0.62322 to 0.61765, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 538ms/step - loss: 0.6703 - accuracy: 0.6148 - val_loss: 0.6177 - val_accuracy: 0.6731
# Epoch 9/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6551 - accuracy: 0.6256
# Epoch 9: val_loss improved from 0.61765 to 0.61183, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 61s 529ms/step - loss: 0.6551 - accuracy: 0.6256 - val_loss: 0.6118 - val_accuracy: 0.6710
# Epoch 10/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6491 - accuracy: 0.6278
# Epoch 10: val_loss improved from 0.61183 to 0.59974, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 533ms/step - loss: 0.6491 - accuracy: 0.6278 - val_loss: 0.5997 - val_accuracy: 0.6839
# Epoch 11/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.6148
# Epoch 11: val_loss did not improve from 0.59974
# 116/116 [==============================] - 55s 476ms/step - loss: 0.6892 - accuracy: 0.6148 - val_loss: 0.6148 - val_accuracy: 0.6710
# Epoch 12/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6637 - accuracy: 0.6367
# Epoch 12: val_loss did not improve from 0.59974
# 116/116 [==============================] - 56s 481ms/step - loss: 0.6637 - accuracy: 0.6367 - val_loss: 0.6638 - val_accuracy: 0.5987
# Epoch 13/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6216 - accuracy: 0.6780
# Epoch 13: val_loss improved from 0.59974 to 0.59392, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 535ms/step - loss: 0.6216 - accuracy: 0.6780 - val_loss: 0.5939 - val_accuracy: 0.7131
# Epoch 14/100
# 116/116 [==============================] - ETA: 0s - loss: 0.8196 - accuracy: 0.6003
# Epoch 14: val_loss did not improve from 0.59392
# 116/116 [==============================] - 55s 472ms/step - loss: 0.8196 - accuracy: 0.6003 - val_loss: 0.7092 - val_accuracy: 0.4790
# Epoch 15/100
# 116/116 [==============================] - ETA: 0s - loss: 1.0238 - accuracy: 0.5223
# Epoch 15: val_loss did not improve from 0.59392
# 116/116 [==============================] - 55s 478ms/step - loss: 1.0238 - accuracy: 0.5223 - val_loss: 0.6459 - val_accuracy: 0.6321
# Epoch 16/100
# 116/116 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.5501
# Epoch 16: val_loss did not improve from 0.59392
# 116/116 [==============================] - 56s 480ms/step - loss: 0.7198 - accuracy: 0.5501 - val_loss: 0.6358 - val_accuracy: 0.6354
# Epoch 17/100
# 116/116 [==============================] - ETA: 0s - loss: 0.7012 - accuracy: 0.5754
# Epoch 17: val_loss did not improve from 0.59392
# 116/116 [==============================] - 56s 481ms/step - loss: 0.7012 - accuracy: 0.5754 - val_loss: 0.6274 - val_accuracy: 0.6785
# Epoch 18/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6794 - accuracy: 0.5862
# Epoch 18: val_loss did not improve from 0.59392
# 116/116 [==============================] - 56s 482ms/step - loss: 0.6794 - accuracy: 0.5862 - val_loss: 0.6237 - val_accuracy: 0.6893
# Epoch 19/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6658 - accuracy: 0.6013
# Epoch 19: val_loss did not improve from 0.59392
# 116/116 [==============================] - 56s 480ms/step - loss: 0.6658 - accuracy: 0.6013 - val_loss: 0.6061 - val_accuracy: 0.6872
# Epoch 20/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6630 - accuracy: 0.6167
# Epoch 20: val_loss improved from 0.59392 to 0.58449, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 63s 540ms/step - loss: 0.6630 - accuracy: 0.6167 - val_loss: 0.5845 - val_accuracy: 0.7001
# Epoch 21/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.6507
# Epoch 21: val_loss improved from 0.58449 to 0.55030, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 534ms/step - loss: 0.6324 - accuracy: 0.6507 - val_loss: 0.5503 - val_accuracy: 0.7044
# Epoch 22/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6468 - accuracy: 0.6715
# Epoch 22: val_loss improved from 0.55030 to 0.51947, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 537ms/step - loss: 0.6468 - accuracy: 0.6715 - val_loss: 0.5195 - val_accuracy: 0.7411
# Epoch 23/100
# 116/116 [==============================] - ETA: 0s - loss: 0.5668 - accuracy: 0.7282
# Epoch 23: val_loss did not improve from 0.51947
# 116/116 [==============================] - 55s 476ms/step - loss: 0.5668 - accuracy: 0.7282 - val_loss: 0.8120 - val_accuracy: 0.7228
# Epoch 24/100
# 116/116 [==============================] - ETA: 0s - loss: 0.6189 - accuracy: 0.6972
# Epoch 24: val_loss improved from 0.51947 to 0.49787, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 539ms/step - loss: 0.6189 - accuracy: 0.6972 - val_loss: 0.4979 - val_accuracy: 0.7573
# Epoch 25/100
# 116/116 [==============================] - ETA: 0s - loss: 0.5378 - accuracy: 0.7355
# Epoch 25: val_loss improved from 0.49787 to 0.49382, saving model to bert_cnn_sentiment_model_2layers.h5
# 116/116 [==============================] - 62s 532ms/step - loss: 0.5378 - accuracy: 0.7355 - val_loss: 0.4938 - val_accuracy: 0.7422
# Epoch 26/100
# 116/116 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.7015
# Epoch 26: val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 474ms/step - loss: 0.5976 - accuracy: 0.7015 - val_loss: 0.8218 - val_accuracy: 0.4617
# Epoch 27/100
# 116/116 [==============================] - ETA: 0s - loss: 0.9135 - accuracy: 0.5015
# Epoch 27: val_loss did not improve from 0.49382
# 116/116 [==============================] - 56s 482ms/step - loss: 0.9135 - accuracy: 0.5015 - val_loss: 0.7569 - val_accuracy: 0.4099
# Epoch 28/100
# 116/116 [==============================] - ETA: 0s - loss: 1.1103 - accuracy: 0.4704
# Epoch 28: val_loss did not improve from 0.49382
# 116/116 [==============================] - 56s
val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 477ms/step - loss: 0.2395 - accuracy: 0.9571 - val_loss: 1.8185 - val_accuracy: 0.7659
# Epoch 93/100
# 116/116 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9803
# Epoch 93: val_loss did not improve from 0.49382
# 116/116 [==============================] - 56s 479ms/step - loss: 0.1720 - accuracy: 0.9803 - val_loss: 2.1302 - val_accuracy: 0.7735
# Epoch 94/100
# 116/116 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9833
# Epoch 94: val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 478ms/step - loss: 0.1344 - accuracy: 0.9833 - val_loss: 2.1959 - val_accuracy: 0.7756
# Epoch 95/100
# 116/116 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9841
# Epoch 95: val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 476ms/step - loss: 0.1176 - accuracy: 0.9841 - val_loss: 2.3109 - val_accuracy: 0.7724
# Epoch 96/100
# 116/116 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7382
# Epoch 96: val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 478ms/step - loss: 0.4994 - accuracy: 0.7382 - val_loss: 1.1410 - val_accuracy: 0.6688
# Epoch 97/100
# 116/116 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.8100
# Epoch 97: val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 478ms/step - loss: 0.7017 - accuracy: 0.8100 - val_loss: 2.5518 - val_accuracy: 0.7238
# Epoch 98/100
# 116/116 [==============================] - ETA: 0s - loss: 1.7900 - accuracy: 0.8291
# Epoch 98: val_loss did not improve from 0.49382
# 116/116 [==============================] - 55s 478ms/step - loss: 1.7900 - accuracy: 0.8291 - val_loss: 3.3678 - val_accuracy: 0.7066
# Epoch 99/100
# 116/116 [==============================] - ETA: 0s - loss: 1.0670 - accuracy: 0.8246
# Epoch 99: val_loss did not improve from 0.49382
# 116/116 [==============================] - 56s 479ms/step - loss: 1.0670 - accuracy: 0.8246 - val_loss: 0.6804 - val_accuracy: 0.7044
# Epoch 100/100
# 116/116 [==============================] - ETA: 0s - loss: 0.2300 - accuracy: 0.9565
# Epoch 100: val_loss did not improve from 0.49382
# 116/116 [==============================] - 56s 479ms/step - loss: 0.2300 - accuracy: 0.9565 - val_loss: 1.8912 - val_accuracy: 0.7530

# %%
# Evaluation
loss, accuracy = model.evaluate([test_inputs, test_attention], test_labels)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# 37/37 [==============================] - 6s 154ms/step - loss: 1.7104 - accuracy: 0.7593
# Test Loss: 1.7103955745697021, Test Accuracy: 0.7592752575874329

# %%
import matplotlib.pyplot as plt

# Extracting data from history
history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

# Getting the number of epochs
epochs = range(1, len(loss) + 1)

# Plot loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Display the plots
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Generate predictions
predictions = model.predict([test_inputs, test_attention])
predicted_labels = (predictions.flatten() > 0.5).astype(int)

# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report
class_report = classification_report(test_labels, predicted_labels, target_names=["Negative", "Positive"])
print("\nClassification Report:")
print(class_report)
# Out:
# 37/37 [==============================] - 8s 162ms/step
# Confusion Matrix:
# [[301 126]
#  [153 579]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.66      0.70      0.68       427
#     Positive       0.82      0.79      0.81       732
#
#     accuracy                           0.76      1159
#    macro avg       0.74      0.75      0.74      1159
# weighted avg       0.76      0.76      0.76      1159
